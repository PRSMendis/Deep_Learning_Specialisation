# %% [markdown]
# Maximum Value of an Arithmetic Expression
#
# Parenthesize an arithmetic expression to maxi- mize its value.
#
# Input. A string s=s0s1⋯s2n of length at most 29. Each symbol at an even position of s is a digit (that is, an integer from 0 to 9) while each symbol at an odd position is one of three operations from {+,−,∗}.
#
# Output. The maximum value of the given arithmetic expression among all possible orders of applying arithmetic operations.

# %%
i = "5-8+7*4-8+9", 200

# %%
i[0]
# Out:
# '5-8+7*4-8+9'

# %%
def find_maximum_value(dataset):
    pass

# %%
import numpy as np
def find_maximum_value(dataset):
    numbers = [num for num in dataset if num.isnumeric()]
    A = np.zeros((len(numbers),len(numbers)), dtype=int)
    for i, num in enumerate(numbers):
        A[i,i] = num
    
    return 1 dataset[1] 2
find_maximum_value(i[0])
# Out:
#   File "<ipython-input-4-dd119a2d74fd>", line 8
#     return 1 dataset[1] 2
#              ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import operator

ops = {
    '+' : operator.add,
    '-' : operator.sub,
    '*' : operator.mul,
    '/' : operator.truediv,  # use operator.div for Python 2
    '%' : operator.mod,
    '^' : operator.xor,
}

def find_maximum_value(dataset):
    numbers = [num for num in dataset if num.isnumeric()]
    operations = [num for num in dataset if not num.isnumeric()]
    A = np.zeros((len(numbers),len(numbers), 2), dtype=int)
    for i, num in enumerate(numbers):
        A[i,i] = num
    
#     return ops[dataset[5]](1,2)
    return operations

find_maximum_value(i[0])
# Out:
# ['-', '+', '*', '-', '+']

# %%
A[:,:,1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-e86a6162d4b5> in <module>
# ----> 1 A[:,:,1]
#
# NameError: name 'A' is not defined

# %%
import numpy as np
import operator

ops = {
    '+' : operator.add,
    '-' : operator.sub,
    '*' : operator.mul,
    '/' : operator.truediv,  # use operator.div for Python 2
    '%' : operator.mod,
    '^' : operator.xor,
}

def find_maximum_value(dataset):
    numbers = [num for num in dataset if num.isnumeric()]
    x = y = len(numbers)
    operations = [num for num in dataset if not num.isnumeric()]
    A = np.zeros((x,y, 2), dtype=int)
    for i, num in enumerate(numbers):
        A[i,i] = num
    for i in range(0,6):
        for j in range(0,6):
            if j > i:
                A[i,j] = i+j
            
    
#     return ops[dataset[5]](1,2)
    return A

B = find_maximum_value(i[0])
print(B[:,:,0])
# Out:
# [[5 1 2 3 4 5]
#  [0 8 3 4 5 6]
#  [0 0 7 5 6 7]
#  [0 0 0 4 7 8]
#  [0 0 0 0 8 9]
#  [0 0 0 0 0 9]]

# %%
import numpy as np
import operator

ops = {
    '+' : operator.add,
    '-' : operator.sub,
    '*' : operator.mul,
    '/' : operator.truediv,  # use operator.div for Python 2
    '%' : operator.mod,
    '^' : operator.xor,
}

def find_maximum_value(dataset):
    numbers = [num for num in dataset if num.isnumeric()]
    x = y = len(numbers)
    operations = [num for num in dataset if not num.isnumeric()]
    A = np.zeros((x,y, 2), dtype=int)
    for i, num in enumerate(numbers):
        A[i,i] = num
    for i in range(0,6):
        for j in range(0,6):
            k = 0
            if j > i:
                print(A[i,j-1, k],operations[i],A[i+1,j, k])
                A[i,j, k] = ops[operations[i]](A[i,j-1,k], A[i+1,j,k]) 
            
    
#     return ops[dataset[5]](1,2)
    return A

B = find_maximum_value(i[0])
print(B[:,:,0])
# Out:
# 5 - 8
# -3 - 0
# -3 - 0
# -3 - 0
# -3 - 0
# 8 + 7
# 15 + 0
# 15 + 0
# 15 + 0
# 7 * 4
# 28 * 0
# 0 * 0
# 4 - 8
# -4 - 0
# 8 + 9
# [[ 5 -3 -3 -3 -3 -3]
#  [ 0  8 15 15 15 15]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4 -4]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]

# %%
import numpy as np
import operator

ops = {
    '+' : operator.add,
    '-' : operator.sub,
    '*' : operator.mul,
    '/' : operator.truediv,  # use operator.div for Python 2
    '%' : operator.mod,
    '^' : operator.xor,
}

def find_maximum_value(dataset):
    numbers = [num for num in dataset if num.isnumeric()]
    x = y = len(numbers)
    operations = [num for num in dataset if not num.isnumeric()]
    A = np.empty((x,y, 2), dtype=int)
    for i, num in enumerate(numbers):
        A[i,i] = num
    for i in range(0,6):
        for j in range(0,6):
            k = 0
            if j > i:
                print(A[i,j-1, k],operations[i],A[i+1,j, k])
                A[i,j, k] = ops[operations[i]](A[i,j-1,k], A[i+1,j,k]) 
            
    
#     return ops[dataset[5]](1,2)
    return A

B = find_maximum_value(i[0])
print(B[:,:,0])
# Out:
# 5 - 8
# -3 - 3
# -6 - 4
# -10 - 5
# -15 - 6
# 8 + 7
# 15 + 5
# 20 + 6
# 26 + 7
# 7 * 4
# 28 * 7
# 196 * 8
# 4 - 8
# -4 - 9
# 8 + 9
# [[   5   -3   -6  -10  -15  -21]
#  [   0    8   15   20   26   33]
#  [   0    0    7   28  196 1568]
#  [   0    0    0    4   -4  -13]
#  [   0    0    0    0    8   17]
#  [   0    0    0    0    0    9]]

# %%
import numpy as np
import operator

ops = {
    '+' : operator.add,
    '-' : operator.sub,
    '*' : operator.mul,
    '/' : operator.truediv,  # use operator.div for Python 2
    '%' : operator.mod,
    '^' : operator.xor,
}

def find_maximum_value(dataset):
    numbers = [num for num in dataset if num.isnumeric()]
    x = y = len(numbers)
    operations = [num for num in dataset if not num.isnumeric()]
    A = np.zeros((x,y, 2), dtype=int)
    for i, num in enumerate(numbers):
        A[i,i] = num
    i = 0
    j = 1
    k = 0
    while j > i:
        print('yaaa')
        print(A[i,j-1, k],operations[i],A[i+1,j, k])
        A[i,j, k] = ops[operations[i]](A[i,j-1,k], A[i+1,j,k])
        i+=1
        j+=1
        if j == y:
            print("TASDOIASDJA",i,j)
            j = j-i +2
            i = j-1
            print(A[:,:,0])
        
            
    

    return A[:,:,0]

find_maximum_value(i[0])
# Out:
# yaaa
# 5 - 8
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
# ...
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 +
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-91299a7a7267> in <module>
#      38     return A[:,:,0]
#      39
# ---> 40 find_maximum_value(i[0])
#
# <ipython-input-10-91299a7a7267> in find_maximum_value(dataset)
#      23     while j > i:
#      24         print('yaaa')
# ---> 25         print(A[i,j-1, k],operations[i],A[i+1,j, k])
#      26         A[i,j, k] = ops[operations[i]](A[i,j-1,k], A[i+1,j,k])
#      27         i+=1
#
# /opt/anaconda3/lib/python3.8/site-packages/ipykernel/iostream.py in write(self, string)
#     402             is_child = (not self._is_master_process())
#     403             # only touch the buffer in the IO thread to avoid races
# --> 404             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     405             if is_child:
#     406                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# /opt/anaconda3/lib/python3.8/site-packages/ipykernel/iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# /opt/anaconda3/lib/python3.8/site-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     489                                  copy_threshold=self.copy_threshold)
#     490             data.group = group
# --> 491         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     492
#     493     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /opt/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
import math
import operator

def calc(a, b, op):
    print(a,b)
    ops = {
        '+' : operator.add,
        '-' : operator.sub,
        '*' : operator.mul,
        '/' : operator.truediv,  # use operator.div for Python 2
        '%' : operator.mod,
        '^' : operator.xor,
    }
    
    ops[op](a, b) 

#     if op == '+':
#         return a + b
#     elif op == '-':
#         return a - b
#     else:
#         return a * b


def MinAndMax(M, m, i, j, operators):

    min_value = math.inf
    max_value = -math.inf
    for k in range(i, j):
        a = calc(M[i][k], M[k+1][j], operators[k])
        b = calc(M[i][k], m[k+1][j], operators[k])
        c = calc(m[i][k], M[k+1][j], operators[k])
        d = calc(m[i][k], m[k+1][j], operators[k])
        min_value = min(min_value, a, b, c, d)
        max_value = max(max_value, a, b, c, d)
    return min_value, max_value


def get_maximum_value(dataset):
    
    operators, operands = [], []

    for i in dataset:
        if i in ['+', '-', '*']:
            operators.append(i)
        else:
            operands.append(int(i))
    

    
    operations = [num for num in dataset if not num.isnumeric()]
    operands = operations

    n = len(operands)
    m = [[None for x in range(n)] for x in range(n)]
    M = [[None for x in range(n)] for x in range(n)]

    for i in range(n):
        m[i][i] = operands[i]
        M[i][i] = operands[i]

    for s in range(1, n):
        for i in range(0, n-s):
            j = i + s
            m[i][j], M[i][j] = MinAndMax(M, m, i, j, operators)

    return M[0][n-1]

# %%
get_maximum_value(i[0])
# Out:
# - +
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-f471300783ff> in <module>
# ----> 1 get_maximum_value(i[0])
#
# <ipython-input-11-90e064c2c4c1> in get_maximum_value(dataset)
#      63         for i in range(0, n-s):
#      64             j = i + s
# ---> 65             m[i][j], M[i][j] = MinAndMax(M, m, i, j, operators)
#      66
#      67     return M[0][n-1]
#
# <ipython-input-11-90e064c2c4c1> in MinAndMax(M, m, i, j, operators)
#      28     max_value = -math.inf
#      29     for k in range(i, j):
# ---> 30         a = calc(M[i][k], M[k+1][j], operators[k])
#      31         b = calc(M[i][k], m[k+1][j], operators[k])
#      32         c = calc(m[i][k], M[k+1][j], operators[k])
#
# <ipython-input-11-90e064c2c4c1> in calc(a, b, op)
#      13     }
#      14
# ---> 15     ops[op](a, b)
#      16
#      17 #     if op == '+':
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
import numpy as np
import operator

ops = {
    '+' : operator.add,
    '-' : operator.sub,
    '*' : operator.mul,
}

def find_maximum_value(dataset):
    numbers = [num for num in dataset if num.isnumeric()]
    x = y = len(numbers)
    operations = [num for num in dataset if not num.isnumeric()]
    A = np.zeros((x,y, 2), dtype=int)
    for i, num in enumerate(numbers):
        A[i,i] = num
    i = 0
    j = 1
    k = 0
    while j > i:
        print('yaaa')
        print(A[i,j-1, k],operations[i],A[i+1,j, k])
        A[i,j, k] = ops[operations[i]](A[i,j-1,k], A[i+1,j,k])
        i+=1
        j+=1
        if j == y:
            print("TASDOIASDJA",i,j)
            j = j-i + 1
            i = j-1
            print(A[:,:,0])
        
            
    

    return A[:,:,0]

B = find_maximum_value(i[0])
# Out:
# yaaa
# 5 - 8
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
# ...
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# [[ 5 -3  0  0  0  0]
#  [ 0  8 15  0  0  0]
#  [ 0  0  7 28  0  0]
#  [ 0  0  0  4 -4  0]
#  [ 0  0  0  0  8 17]
#  [ 0  0  0  0  0  9]]
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# TASDOIASDJA 5 6
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-38ffcad18cc7> in <module>
#      38     return A[:,:,0]
#      39
# ---> 40 B = find_maximum_value(i[0])
#
# <ipython-input-17-38ffcad18cc7> in find_maximum_value(dataset)
#      31             j = j-i + 1
#      32             i = j-1
# ---> 33             print(A[:,:,0])
#      34
#      35
#
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/arrayprint.py in _array_str_implementation(a, max_line_width, precision, suppress_small, array2string)
#    1515         return _guarded_repr_or_str(np.ndarray.__getitem__(a, ()))
#    1516
# -> 1517     return array2string(a, max_line_width, precision, suppress_small, ' ', "")
#    1518
#    1519
#
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/arrayprint.py in array2string(a, max_line_width, precision, suppress_small, separator, prefix, style, formatter, threshold, edgeitems, sign, floatmode, suffix, legacy)
#     690         return "[]"
#     691
# --> 692     return _array2string(a, options, separator, prefix)
#     693
#     694
#
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/arrayprint.py in wrapper(self, *args, **kwargs)
#     466             repr_running.add(key)
#     467             try:
# --> 468                 return f(self, *args, **kwargs)
#     469             finally:
#     470                 repr_running.discard(key)
#
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/arrayprint.py in _array2string(a, options, separator, prefix)
#     481     # subclasses yet, and we also need to avoid recursion issues in
#     482     # _formatArray with subclasses which return 0d arrays in place of scalars
# --> 483     data = asarray(a)
#     484     if a.shape == ():
#     485         a = data
#
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# KeyboardInterrupt:

# %%
B[:,:,0]
# Out:
# array([[   5,   -3,   -6,  -10,  -15,  -21],
#        [   0,    8,   15,   20,   26,   33],
#        [   0,    0,    7,   28,  196, 1568],
#        [   0,    0,    0,    4,   -4,  -13],
#        [   0,    0,    0,    0,    8,   17],
#        [   0,    0,    0,    0,    0,    9]])

# %%
import numpy as np
import operator

ops = {
    '+' : operator.add,
    '-' : operator.sub,
    '*' : operator.mul,
    '/' : operator.truediv,  # use operator.div for Python 2
    '%' : operator.mod,
    '^' : operator.xor,
}

def find_maximum_value(dataset):
    numbers = [num for num in dataset if num.isnumeric()]
    x = y = len(numbers)
    operations = [num for num in dataset if not num.isnumeric()]
    A = np.zeros((x,y, 2), dtype=int)
    for i, num in enumerate(numbers):
        A[i,i] = num
    i = 0
    j = 1
    k = 0
    q = 0
    while j > i:
        print('yaaa')
        print(A[i,j-1, k],operations[i],A[i+1,j, k])
        A[i,j, k] = q
        q+=1
#         A[i,j, k] = ops[operations[i]](A[i,j-1,k], A[i+1,j,k])
        i+=1
        j+=1
        if j == y:
            y -= 1
            print(f"x:{x}, y:{y}, j:{j}, i:{i}")
            j = j-i
            i = j+x-y-1
            
            print(A[:,:,0])
            
        
            
    

    return A[:,:,0]

find_maximum_value(i[0])
# Out:
# yaaa
# 5 - 8
# yaaa
# 8 + 7
# yaaa
# 7 * 4
# yaaa
# 4 - 8
# yaaa
# 8 + 9
# x:6, y:5, j:6, i:5
# [[5 0 0 0 0 0]
#  [0 8 1 0 0 0]
#  [0 0 7 2 0 0]
#  [0 0 0 4 3 0]
#  [0 0 0 0 8 4]
#  [0 0 0 0 0 9]]
# array([[5, 0, 0, 0, 0, 0],
#        [0, 8, 1, 0, 0, 0],
#        [0, 0, 7, 2, 0, 0],
#        [0, 0, 0, 4, 3, 0],
#        [0, 0, 0, 0, 8, 4],
#        [0, 0, 0, 0, 0, 9]])

# %%
import numpy as np
import operator

ops = {
    '+' : operator.add,
    '-' : operator.sub,
    '*' : operator.mul,
    '/' : operator.truediv,  # use operator.div for Python 2
    '%' : operator.mod,
    '^' : operator.xor,
}

def find_maximum_value(dataset):
    numbers = [num for num in dataset if num.isnumeric()]
    x = y = len(numbers)
    operations = [num for num in dataset if not num.isnumeric()]
    A = np.zeros((x,y, 2), dtype=int)
    for i, num in enumerate(numbers):
        A[i,i] = num
    i = 0
    j = 1
    k = 0
    q = 0
    
    d = 1
    
    while d < y:
        j = d
        while j < y :
            print('yaaa')
#             print(A[i,j-1, k],operations[i],A[i+1,j, k])
            A[i,j, k] = q
            q+=1
#             A[i,j, k] = ops[operations[i]](A[i,j-1,k], A[i+1,j,k])
            i+=1
            j+=1
#             if j == y-1:
#                 print(f"x:{x}, y:{y}, j:{j}, i:{i}")
#                 j = j-i
#                 i = j+x-y-1
        i = 0
        d += 1
        j = d
        
            
    

    return A[:,:,0]

find_maximum_value(i[0])
# Out:
# yaaa
# yaaa
# yaaa
# yaaa
# yaaa
# yaaa
# yaaa
# yaaa
# yaaa
# yaaa
# yaaa
# yaaa
# yaaa
# yaaa
# yaaa
# array([[    5,    -3,   -18,   -61,     8, -2275],
#        [    0,     8,    15,    43,   -69,  2283],
#        [    0,     0,     7,    28,  -112,  2352],
#        [    0,     0,     0,     4,    -4,   -21],
#        [    0,     0,     0,     0,     8,    17],
#        [    0,     0,     0,     0,     0,     9]])

# %%
import numpy as np
import operator

ops = {
    '+' : operator.add,
    '-' : operator.sub,
    '*' : operator.mul,
}

def find_maximum_value(dataset):
    numbers = [num for num in dataset if num.isnumeric()]
    x = y = len(numbers)
    operations = [num for num in dataset if not num.isnumeric()]
    A = np.zeros((x,y, 2), dtype=int)
    for i, num in enumerate(numbers):
        A[i,i] = num
    i = 0
    j = 1
    k = 0
    q = 0
    
    d = 1
    
    while d < y:
        j = d
        while j < y :
            print('yaaa')
#             print(A[i,j-1, k],operations[i],A[i+1,j, k])
            A[i,j, k] = q
            q+=1
#             A[i,j, k] = ops[operations[i]](A[i,j-1,k], A[i+1,j,k])
            i+=1
            j+=1
#             if j == y-1:
#                 print(f"x:{x}, y:{y}, j:{j}, i:{i}")
#                 j = j-i
#                 i = j+x-y-1
        i = 0
        d += 1
        j = d
        
            
    

    return A[:,:,0]

find_maximum_value(i[0])
# Out:
# yaaa
# yaaa
# yaaa
# yaaa
# yaaa
# yaaa
# yaaa
# yaaa
# yaaa
# yaaa
# yaaa
# yaaa
# yaaa
# yaaa
# yaaa
# array([[ 5,  0,  5,  9, 12, 14],
#        [ 0,  8,  1,  6, 10, 13],
#        [ 0,  0,  7,  2,  7, 11],
#        [ 0,  0,  0,  4,  3,  8],
#        [ 0,  0,  0,  0,  8,  4],
#        [ 0,  0,  0,  0,  0,  9]])

# %%
import numpy as np
import operator

ops = {
    '+' : operator.add,
    '-' : operator.sub,
    '*' : operator.mul,
}

def find_maximum_value(dataset):
    numbers = [num for num in dataset if num.isnumeric()]
    x = y = len(numbers)
    operations = [num for num in dataset if not num.isnumeric()]
    A = np.zeros((x,y, 2), dtype=int)
    for i, num in enumerate(numbers):
        A[i,i] = num
    print(A[:,:,0])
    i = 0
    j = 1
    k = 0
    q = 0
    
    d = 1
    
    while d < y:
        j = d
        
        while j < y :
            
            print('yaaa')
#             A[i,j, k] = q
#             q+=1
            A[i,j, k] = ops[operations[i]](A[i,j-1,k], A[i+1,j,k])
#             A[i,j, 0] = max(ops[operations[i]](A[i,j-1,0], A[i+1,j,0]), ops[operations[i]](A[i,j-1,1], A[i+1,j,1]))
#             A[i,j, 1] = min(ops[operations[i]](A[i,j-1,0], A[i+1,j,0]), ops[operations[i]](A[i,j-1,1], A[i+1,j,1]))
            
    
            i+=1
            j+=1
        i = 0
        d += 1
        j = d
        
            
    

    return A[:,:,0]

B = find_maximum_value(i[0])
# Out:
# [[5 0 0 0 0 0]
#  [0 8 0 0 0 0]
#  [0 0 7 0 0 0]
#  [0 0 0 4 0 0]
#  [0 0 0 0 8 0]
#  [0 0 0 0 0 9]]
# yaaa
# yaaa
# yaaa
# yaaa
# yaaa
# yaaa
# yaaa
# yaaa
# yaaa
# yaaa
# yaaa
# yaaa
# yaaa
# yaaa
# yaaa

# %%
B[0,:]
# Out:
# array([    5,    -3,   -18,   -61,     8, -2275])

# %%
B
# Out:
# array([[    5,    -3,   -18,   -61,     8, -2275],
#        [    0,     8,    15,    43,   -69,  2283],
#        [    0,     0,     7,    28,  -112,  2352],
#        [    0,     0,     0,     4,    -4,   -21],
#        [    0,     0,     0,     0,     8,    17],
#        [    0,     0,     0,     0,     0,     9]])

# %%
import numpy as np
import operator

ops = {
    '+' : operator.add,
    '-' : operator.sub,
    '*' : operator.mul,
}

def find_maximum_value(dataset):
    numbers = [num for num in dataset if num.isnumeric()]
    x = y = len(numbers)
    operations = [num for num in dataset if not num.isnumeric()]
    A = np.zeros((x,y, 2), dtype=int)
    for i, num in enumerate(numbers):
        A[i,i] = num
    print(A[:,:,0])
    i = 0
    j = 1
    k = 0
    q = 0
    
    d = 1
    
    while d < y:
        j = d
        
        while j < y :
            
            print('yaaa')
#             A[i,j, k] = q
#             q+=1
            A[i,j, k] = ops[operations[i]](A[i,i,k], A[i+1,j,k])
#             A[i,j, 0] = max(ops[operations[i]](A[i,j-1,0], A[i+1,j,0]), ops[operations[i]](A[i,j-1,1], A[i+1,j,1]))
#             A[i,j, 1] = min(ops[operations[i]](A[i,j-1,0], A[i+1,j,0]), ops[operations[i]](A[i,j-1,1], A[i+1,j,1]))
            
    
            i+=1
            j+=1
        i = 0
        d += 1
        j = d
        
            
    

    return A[:,:,0]

find_maximum_value(i[0])
# Out:
# [[5 0 0 0 0 0]
#  [0 8 0 0 0 0]
#  [0 0 7 0 0 0]
#  [0 0 0 4 0 0]
#  [0 0 0 0 8 0]
#  [0 0 0 0 0 9]]
# yaaa
# yaaa
# yaaa
# yaaa
# yaaa
# yaaa
# yaaa
# yaaa
# yaaa
# yaaa
# yaaa
# yaaa
# yaaa
# yaaa
# yaaa
# array([[  5,  -3, -10, -31,  25,  88],
#        [  0,   8,  15,  36, -20, -83],
#        [  0,   0,   7,  28, -28, -91],
#        [  0,   0,   0,   4,  -4, -13],
#        [  0,   0,   0,   0,   8,  17],
#        [  0,   0,   0,   0,   0,   9]])

# %%
import numpy as np
import operator

ops = {
    '+' : operator.add,
    '-' : operator.sub,
    '*' : operator.mul,
}

def find_maximum_value(dataset):
    numbers = [num for num in dataset if num.isnumeric()]
    x = y = len(numbers)
    operations = [num for num in dataset if not num.isnumeric()]
    A = np.zeros((x,y, 2), dtype=int)
    for i, num in enumerate(numbers):
        A[i,i] = num
    print(A[:,:,0])
    i = 0
    j = 1
    k = 0
    q = 0
    
    d = 1
    
    while d < y:
        j = d
        
        while j < y :
            
            print('yaaa')
#             A[i,j, k] = q
#             q+=1
            print(f"A:{type(A)}, cart:{type((i,j))}")
            A[i,j, k] = max_at_pos(A=A, cart=(i,j))
#             A[i,j, 0] = max(ops[operations[i]](A[i,j-1,0], A[i+1,j,0]), ops[operations[i]](A[i,j-1,1], A[i+1,j,1]))
#             A[i,j, 1] = min(ops[operations[i]](A[i,j-1,0], A[i+1,j,0]), ops[operations[i]](A[i,j-1,1], A[i+1,j,1]))
            
    
            i+=1
            j+=1
        i = 0
        d += 1
        j = d
        
            
    

    return A[:,:,0]


def max_at_pos(A, cart):
    '''
    Input: Array, column, cartesion position
    Output: largest possible value (negative, and pos)
    
    Number of times needed to iterate = j-i
    '''
    i, j = cart
    Results = []
    k = 0
    
    for z in range(0,j-i):
        x = A[i+1+z,j,k] + A[i,z,k]
    
    return x

find_maximum_value(i[0])
# Out:
# [[5 0 0 0 0 0]
#  [0 8 0 0 0 0]
#  [0 0 7 0 0 0]
#  [0 0 0 4 0 0]
#  [0 0 0 0 8 0]
#  [0 0 0 0 0 9]]
# yaaa
# A:<class 'numpy.ndarray'>, cart:<class 'tuple'>
# yaaa
# A:<class 'numpy.ndarray'>, cart:<class 'tuple'>
# yaaa
# A:<class 'numpy.ndarray'>, cart:<class 'tuple'>
# yaaa
# A:<class 'numpy.ndarray'>, cart:<class 'tuple'>
# yaaa
# A:<class 'numpy.ndarray'>, cart:<class 'tuple'>
# yaaa
# A:<class 'numpy.ndarray'>, cart:<class 'tuple'>
# yaaa
# A:<class 'numpy.ndarray'>, cart:<class 'tuple'>
# yaaa
# A:<class 'numpy.ndarray'>, cart:<class 'tuple'>
# yaaa
# A:<class 'numpy.ndarray'>, cart:<class 'tuple'>
# yaaa
# A:<class 'numpy.ndarray'>, cart:<class 'tuple'>
# yaaa
# A:<class 'numpy.ndarray'>, cart:<class 'tuple'>
# yaaa
# A:<class 'numpy.ndarray'>, cart:<class 'tuple'>
# yaaa
# A:<class 'numpy.ndarray'>, cart:<class 'tuple'>
# yaaa
# A:<class 'numpy.ndarray'>, cart:<class 'tuple'>
# yaaa
# A:<class 'numpy.ndarray'>, cart:<class 'tuple'>
# array([[ 5, 13, 20, 24, 32, 41],
#        [ 0,  8,  7, 12, 15, 21],
#        [ 0,  0,  7,  4,  8, 16],
#        [ 0,  0,  0,  4,  8,  9],
#        [ 0,  0,  0,  0,  8,  9],
#        [ 0,  0,  0,  0,  0,  9]])

# %%
import numpy as np
import operator

ops = {
    '+' : operator.add,
    '-' : operator.sub,
    '*' : operator.mul,
}

def find_maximum_value(dataset):
    numbers = [num for num in dataset if num.isnumeric()]
    x = y = len(numbers)
    operations = [num for num in dataset if not num.isnumeric()]
    A = np.zeros((x,y, 2), dtype=int)
    for i, num in enumerate(numbers):
        A[i,i] = num
    print(A[:,:,0])
    i = 0
    j = 1
    k = 0
    q = 0
    
    d = 1
    
    while d < y:
        j = d
        
        while j < y :
            
            print('yaaa')
#             A[i,j, k] = q
#             q+=1
            print(f"A:{type(A)}, cart:{type((i,j))}")
            A[i,j, k] = max_at_pos(A=A, cart=(i,j), op=ops[operations[i]])
#             A[i,j, 0] = max(ops[operations[i]](A[i,j-1,0], A[i+1,j,0]), ops[operations[i]](A[i,j-1,1], A[i+1,j,1]))
#             A[i,j, 1] = min(ops[operations[i]](A[i,j-1,0], A[i+1,j,0]), ops[operations[i]](A[i,j-1,1], A[i+1,j,1]))
            
    
            i+=1
            j+=1
        i = 0
        d += 1
        j = d
        
            
    

    return A[:,:,0]


def max_at_pos(A, cart, op):
    '''
    Input: Array, column, cartesion position
    Output: largest possible value (negative, and pos)
    
    Number of times needed to iterate = j-i
    '''
    i, j = cart
    Results = []
    k = 0
    
    for z in range(0,j-i):
#         x = A[i+1+z,j,k] + A[i,z,k]
#         x = A[i+1+z,j,k] + A[i,z,k]
        print(op, A[i+1+z,j,k], A[i,z,k])
        x = op(A[i,z,k], A[i+1+z,j,k])
    
        Results.append(x)
    
    return max(Results)

find_maximum_value(i[0])
# Out:
# [[5 0 0 0 0 0]
#  [0 8 0 0 0 0]
#  [0 0 7 0 0 0]
#  [0 0 0 4 0 0]
#  [0 0 0 0 8 0]
#  [0 0 0 0 0 9]]
# yaaa
# A:<class 'numpy.ndarray'>, cart:<class 'tuple'>
# <built-in function sub> 8 5
# yaaa
# A:<class 'numpy.ndarray'>, cart:<class 'tuple'>
# <built-in function add> 7 0
# yaaa
# A:<class 'numpy.ndarray'>, cart:<class 'tuple'>
# <built-in function mul> 4 0
# yaaa
# A:<class 'numpy.ndarray'>, cart:<class 'tuple'>
# <built-in function sub> 8 0
# yaaa
# A:<class 'numpy.ndarray'>, cart:<class 'tuple'>
# <built-in function add> 9 0
# yaaa
# A:<class 'numpy.ndarray'>, cart:<class 'tuple'>
# <built-in function sub> 7 5
# <built-in function sub> 7 -3
# yaaa
# A:<class 'numpy.ndarray'>, cart:<class 'tuple'>
# <built-in function add> 0 0
# <built-in function add> 4 8
# yaaa
# A:<class 'numpy.ndarray'>, cart:<class 'tuple'>
# <built-in function mul> -8 0
# <built-in function mul> 8 0
# yaaa
# A:<class 'numpy.ndarray'>, cart:<class 'tuple'>
# <built-in function sub> 9 0
# <built-in function sub> 9 0
# yaaa
# A:<class 'numpy.ndarray'>, cart:<class 'tuple'>
# <built-in function sub> 12 5
# <built-in function sub> 0 -3
# <built-in function sub> 4 -2
# yaaa
# A:<class 'numpy.ndarray'>, cart:<class 'tuple'>
# <built-in function add> 0 0
# <built-in function add> -8 8
# <built-in function add> 8 7
# yaaa
# A:<class 'numpy.ndarray'>, cart:<class 'tuple'>
# <built-in function mul> -9 0
# <built-in function mul> 9 0
# <built-in function mul> 9 7
# yaaa
# A:<class 'numpy.ndarray'>, cart:<class 'tuple'>
# <built-in function sub> 15 5
# <built-in function sub> 0 -3
# <built-in function sub> -8 -2
# <built-in function sub> 8 -3
# yaaa
# A:<class 'numpy.ndarray'>, cart:<class 'tuple'>
# <built-in function add> 63 0
# <built-in function add> -9 8
# <built-in function add> 9 7
# <built-in function add> 9 12
# yaaa
# A:<class 'numpy.ndarray'>, cart:<class 'tuple'>
# <built-in function sub> 63 5
# <built-in function sub> 63 -3
# <built-in function sub> -9 -2
# <built-in function sub> 9 -3
# <built-in function sub> 9 6
# array([[ 5, -3, -2, -3,  6,  7],
#        [ 0,  8,  7, 12, 15, 63],
#        [ 0,  0,  7,  0,  0, 63],
#        [ 0,  0,  0,  4, -8, -9],
#        [ 0,  0,  0,  0,  8,  9],
#        [ 0,  0,  0,  0,  0,  9]])
